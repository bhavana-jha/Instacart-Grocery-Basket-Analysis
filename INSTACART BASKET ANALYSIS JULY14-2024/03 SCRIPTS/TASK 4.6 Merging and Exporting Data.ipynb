# %% [markdown]
# # This script includes:
# 1. Importing Libraries
# 2. Defining Path
# 3. IMPORTING “orders_products_combined.pkl
# 4. Checking shape of imported file
# 5. Merging "orders_products_combined" with cleaned products data set
# 6. Confirming results using the merge flag
# 7. Exporting the merged file using pickle format

# %% [markdown]
# # 1. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Defining Path

# %%
path= r'/Users/navneetjha/Desktop/Career foundry Docs/exercises/Data Immersion /Achievement 4/INSTACART BASKET ANALYSIS JULY14-2024'

# %%
path
# Out:
# '/Users/navneetjha/Desktop/Career foundry Docs/exercises/Data Immersion /Achievement 4/INSTACART BASKET ANALYSIS JULY14-2024'

# %% [markdown]
# # 3. IMPORTING “orders_products_combined.pkl

# %%
df_orders_products_combined=pd.read_pickle(os.path.join(path, '02 DATA', 'PREPARED DATA','orders_products_combined.pkl'))

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %% [markdown]
# # 4. Checking shape of imported file

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# # 5. Merging "orders_products_combined" with cleaned products data set.

# %%
#Importing Cleaned Product data set
df_prods=pd.read_csv(os.path.join(path, '02 DATA', 'PREPARED DATA','products_checked.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Merging "df_prods" and "df_orders_products_combined".
df_merged_large=df_prods.merge(df_orders_products_combined, on = 'product_id', indicator = False)

# %%
df_merged_large
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32434207         49692       49688      Fresh Foaming Cleanser        73
# 32434208         49692       49688      Fresh Foaming Cleanser        73
# 32434209         49692       49688      Fresh Foaming Cleanser        73
# 32434210         49692       49688      Fresh Foaming Cleanser        73
# 32434211         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  \
# ...

# %% [markdown]
# # 6. Confirming results using the merge flag

# %%
# Question 6. Confirming results using the merge flag
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # 7. Exporting the merged file using pickle format

# %%
# Question 7 Exporting the merged file using pickle format
df_merged_large.to_pickle(os.path.join(path, '02 DATA', 'PREPARED DATA','ords_prods_merge. pkl'))
